# %% [markdown]
# ## Data Parsing

# %% [markdown]
# ### Data for api_details table

# %%
api_details = {}
import mysql.connector

# Connect to MySQL
cnx = mysql.connector.connect(
    host='xxx',
    user='xxx',
    password='xxx',
    database='xxx'
)

cursor = cnx.cursor()
select_query = "SELECT a1.base_url, a1.followers, a1.resources, a1.ratings_votes, a1.documentation, a2.pageCount, a2.pageComment, a2.discussionCount FROM aboutPage a1 JOIN discussionPage a2 ON a1.base_url = a2.base_url"
#select_query = "SELECT base_url FROM discussionPage WHERE base_url not in (select base_url from aboutPage)"

cursor.execute(select_query)
 
results = cursor.fetchall()

for result in results:
        base_url = result[0]
        base_url = base_url[:255]
        followers = result[1]
        resources = result[2]
        ratings_votes = result[3]
        documentation = result[4]
        pageCount = result[5]
        pageComment = result[6]
        discussionCount = result[7]
        if ratings_votes != '':
            rating_parts = ratings_votes.split(" - ")
            ratings = rating_parts[0].split(": ")[1]
            votes = rating_parts[1].split(": ")[1]
        api_details[base_url] = {
            'followers': int(followers.replace(',', '')),
            'resources': resources,
            'ratings': float(ratings),
            'votes': int(votes),
            'documentation': int(documentation),
            'discussion_page_count':int(pageCount),
            'pageComment':int(pageComment),
            'discussionCount':int(discussionCount)
        }
cnx.close()

# %%
import mysql.connector

# Connect to MySQL
cnx = mysql.connector.connect(
    host='xxx',
    user='xxx',
    password='xxx',
    database='xxx'
)

cursor = cnx.cursor()

# Prepare the SQL statement for the insert operation
insert_api_details = "INSERT INTO api_details (base_url, followers, resources, ratings, votes, documentation, discussion_page_count, pageComment, discussionCount) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"

# Iterate over the items in the api_details dictionary
for base_url, details in api_details.items():
    followers = int(details['followers'])
    resources = details['resources']
    ratings = float(details['ratings'])
    votes =  int(details['votes'])
    documentation =  int(details['documentation'])
    discussion_page_count = int(details['discussion_page_count'])
    pageComment =  int(details['pageComment'])
    discussionCount =  int(details['discussionCount'])
    

    # Check if URL already exists in the database
    select_query = "SELECT base_url FROM api_details WHERE base_url = %s"
    cursor.execute(select_query, (base_url,))
    existing_url = cursor.fetchone()

    if existing_url:
        continue
    else:
        # Execute the insert operation for each URL and details
        cursor.execute(insert_api_details, (base_url, followers, resources, ratings, votes, documentation, discussion_page_count, pageComment, discussionCount))

# Commit the changes and close the connection
cnx.commit()
cnx.close()

# %% [markdown]
# ### Data for api_info table

# %%
import re
import mysql.connector
from urllib.parse import urlparse

api_details = {}
api_info ={}
# Connect to MySQL
cnx = mysql.connector.connect(
    host='xxx',
    user='xxx',
    password='xxx',
    database='xxx'
)

cursor = cnx.cursor()
select_query = "SELECT base_url, top_des, endpoint_des, api_url, hostname from endpointPage"

cursor.execute(select_query)
 
results = cursor.fetchall()

for result in results:
    base_url = result[0]
    print(base_url)
    top_des = result[1]
    endpoint_des = result[2]
    api_url = result[3]
    hostname = result[4]
    
    if hostname =='':
        parsed_url = urlparse(api_url)
        hostname = parsed_url.hostname
        
    # Splitting the string based on '|' and removing leading/trailing spaces
    split_data = top_des.split('|')
    split_data = [item.strip() for item in split_data]
    # Extracting the different values
    job_search = split_data[0]  # "JobSearchFREEByAva"
#     last_updated = split_data[1]  # "Updated a month ago"
#     print(last_updated)
    
    # Check if split_data has at least 2 elements before accessing index 1
    if len(split_data) > 1:
        last_updated = split_data[1]
    else:
        last_updated = ''  # Set a default value if split_data doesn't have enough elements


    jobs = ''
    print(split_data)
    try:
        category = split_data[2].split('Popularity')[0].strip()  # "Jobs"
        category = category[1:] if category.startswith('-') else category  # Removing the leading '-' if present
        popularity_data = split_data[2].split('Popularity') if len(split_data) > 2 else []
        popularity_value = popularity_data[1].split('/')[0].strip() if len(popularity_data) > 1 else 0.0
        popularity = float('.'.join(popularity_value.split()[-1].split('.')[:2])) if popularity_value else 0.0

        latency_data = split_data[2].split('Latency') if len(split_data) > 2 else []
        latency = int(latency_data[1].split('ms')[0].strip().replace(',', '')) if len(latency_data) > 1 else 0

        service_level_data = split_data[2].split('Service Level') if len(split_data) > 2 else []
        service_level = int(service_level_data[1].split('%')[0]) if len(service_level_data) > 1 else 0
        
        

    except IndexError:
        # Handle the case where the string does not match the expected pattern
        print(base_url,"Error: Unable to extract values from the string.")
 
    
    api_info[base_url] = {
    'category': category,
    'last_updated': last_updated,
    'endpoint_des': endpoint_des,
    'popularity': popularity,
    'latency': latency,
    'service_level': service_level,
    'api_url': api_url,
    'hostname': hostname
        
}
cnx.close()
# Out:
# https://rapidapi.com/musex/api/tes130/
# ['TESFREEBymusex', 'Updated 8ヶ月前', 'CybersecurityPopularity0.3 / 10Latency431msService Level100%Health CheckN/A']
# https://rapidapi.com/api-method-api-method-default/api/mitre-att-ck-framework/
# ['MITRE ATT&CK FrameworkFREEMIUMByAPI Method', 'Updated 2 months ago', 'CybersecurityPopularity8.3 / 10Latency822msService Level100%Health CheckN/A']
# https://rapidapi.com/srivishnuk90/api/spamsafe/
# ['SpamSafePAIDBySri Vishnu', 'Updated 4 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/sujoyk211/api/true_caller-api/
# ['True_Caller APIFREEMIUMByDUPELICATE GAMERZ', 'Updated месяц назад', 'CybersecurityPopularity9 / 10Latency5,367msService Level100%Health Check100%']
# https://rapidapi.com/GlyphDLP/api/glyph-dlp/
# ['Glyph DLPFREEByGlyphDLP', 'Updated 3 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/fptlapwifivn/api/demo-project51070/
# ['👋 Demo ProjectFREEByLắp WiFi FPT', 'Updated hace 4 meses', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/alexandrosmagos/api/sus-guru-malicious-website-ai-detector-api/
# ['Sus Guru Malicious Website AI Detector APIFREEByalexandrosmagos', 'Updated 9 months ago', 'CybersecurityPopularity0 / 10Latency52msService Level0%Health CheckN/A']
# https://rapidapi.com/yottanext-yottanext-default/api/phishyscan-api/
# ['PhishyScan APIFREEMIUMByYottaNext', 'Updated 18 days ago', 'CybersecurityPopularity8.7 / 10Latency1,317msService Level75%Health CheckN/A']
# https://rapidapi.com/rustychapin/api/known-vulnerability-search/
# ['Known Vulnerability SearchPAIDByrusty chapin', 'Updated a month ago', 'CybersecurityPopularity6.7 / 10Latency1,854msService Level100%Health Check0%']
# https://rapidapi.com/wyattb/api/amazon-web-services-aws-guardduty-detector/
# ['Amazon Web Services (AWS) GuardDuty DetectorFREEBywyattb', 'Updated 6ヶ月前', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/vesuviusoe/api/spamip/
# ['SpamIPFREEMIUMByVesuvius Khatiwada', 'Updated 2 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/vishwaraj/api/secure-password-generator3/
# ['Secure password generatorFREEMIUMByvraj', 'Updated 4 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/michaelryanchitwood/api/psobfuscate/
# ['PsObfuscateFREEMIUMByI am Jakoby', 'Updated 2달 전', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/lazenifofana/api/domain-generation-algorithm-dga-detection-api/
# ['Domain Generation Algorithm(DGA) Detection APIFREEMIUMByFraudapi', 'Updated 7 months ago', 'CybersecurityPopularity1.4 / 10Latency6,894msService Level25%Health CheckN/A']
# https://rapidapi.com/joshghent/api/loginllama/
# ['LoginLlamaFREEByjoshghent', 'Updated 4 महीने पहले', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/tomwimmenhove/api/netdetective/
# ['NetDetectiveFREEMIUMByTom Wimmenhove', 'Updated 8 months ago', 'CybersecurityPopularity8.9 / 10Latency1,408msService Level100%Health CheckN/A']
# https://rapidapi.com/aquariuswolf940/api/arespass/
# ['ArespassPAIDByWolf 940', 'Updated 13 days ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/salmanakbar264/api/random-password-generator-api/
# ['Random Password Generator APIFREEBySuleman Akbar', 'Updated 5 months ago', 'CybersecurityPopularity0.2 / 10Latency99msService Level0%Health CheckN/A']
# https://rapidapi.com/narukaakshat/api/ip-anonymizer/
# ['IP AnonymizerFREEMIUMByprobiex', 'Updated לפני 7 חודשים', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/cavsn/api/email-social-media-checker/
# ['Email Social Media CheckerFREEMIUMBycavsn', 'Updated 4 месяца назад', 'CybersecurityPopularity0.4 / 10Latency11,087msService Level0%Health CheckN/A']
# https://rapidapi.com/entrusttitle-entrusttitle-default/api/zorrosign-esign/
# ['ZorroSign - EsignFREEByEntrustTitle', 'Updated 10 months ago', 'CybersecurityPopularity0.1 / 10Latency288msService Level0%Health CheckN/A']
# https://rapidapi.com/k3ru/api/mact-ai/
# ['Mact AIPAIDByk3ru', 'Updated hace 3 meses', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/gre-development-ltd-gre-development-ltd-default/api/greip/
# ['GreipFREEMIUMByGreip', 'Updated 10 months ago', 'CybersecurityPopularity7.8 / 10Latency1,233msService Level98%Health CheckN/A']
# https://rapidapi.com/ryanwil1/api/ip-threat-lookup/
# ['IP Threat LookupFREEMIUMByryanwil1', 'Updated 9 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/matteoalvazzi/api/pawscan/
# ['PawScanFREEByMatteo Alvazzi Delfrate', 'Updated 9 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/contactazguer/api/url-parsing-and-changing/
# ['URL parsing and changingFREEMIUMByazguer service', 'Updated 5 months ago', 'CybersecurityPopularity4.9 / 10Latency2,069msService Level100%Health CheckN/A']
# https://rapidapi.com/vishwaraj/api/tempmailchecker/
# ['TempmailcheckerFREEMIUMByvraj', 'Updated 19 days ago', 'CybersecurityPopularity6.9 / 10Latency473msService Level100%Health CheckN/A']
# https://rapidapi.com/bareq/api/sshscan-io/
# ['sshscan.ioPAIDBybareq', 'Updated 17 days ago', 'CybersecurityHealth Check100%']
# https://rapidapi.com/arraial-epico-arraial-epico-default/api/inline-hashes-api/
# ['Inline Hashes APIFREEMIUMByArraial Epico', 'Updated 2 months ago', 'CybersecurityPopularity5.2 / 10Latency573msService Level100%Health CheckN/A']
# https://rapidapi.com/cavsn/api/token-scanner-multichain-honeypot-checker-multichain/
# ['Token Scanner Multichain', 'Honeypot Checker MultichainFREEMIUMBycavsn', 'Updated a month ago', 'CybersecurityPopularity7.4 / 10Latency1,263msService Level100%Health CheckN/A']
# https://rapidapi.com/info-m8Se5i-Kk/api/istmp-email/
# ['istmp.emailFREEMIUMByGiMucco PTE LTD', 'Updated 5 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/safu92/api/simple-otp/
# ['Simple OtpFREEMIUMBysafu92', 'Updated 5ヶ月前', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/anandhimanshu/api/public-cloud-threat-intelligence/
# ['Public Cloud Threat intelligenceFREEByanandhimanshu', 'Updated a month ago', 'CybersecurityHealth Check100%']
# https://rapidapi.com/marook332-tgQpJK5rj/api/password-generator20/
# ['Password GeneratorFREEMIUMByArmin Jager', 'Updated 7 months ago', 'CybersecurityPopularity4.9 / 10Latency125msService Level100%Health CheckN/A']
# https://rapidapi.com/rungutan-rungutan-default/api/rungutan-fastest-load-tester-in-the-jungle/
# ['Rungutan - Fastest Load Tester in the JungleFREEMIUMByRungutan', 'Updated 9 months ago', 'CybersecurityPopularity0 / 10Latency616msService Level100%Health CheckN/A']
# https://rapidapi.com/evlar-evlar-default/api/ip-blacklist-risk-detector/
# ['IP Blacklist Risk DetectorFREEMIUMByEvlar LLC', 'Updated 6 месяцев назад', 'CybersecurityPopularity6.7 / 10Latency1,645msService Level100%Health CheckN/A']
# https://rapidapi.com/fdis-fdis-default/api/aka-bmp/
# ['Aka BMPFREEMIUMByFDIS', 'Updated 3 months ago', 'CybersecurityPopularity7.9 / 10Latency831msService Level100%Health CheckN/A']
# https://rapidapi.com/gboban70/api/bis-bip-0039/
# ['bis/bip-0039FREEMIUMByGoran Boban', 'Updated 4 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/pratik97186/api/subfinder-2/
# ['Subfinder 2FREEByPratik Choudhary', 'Updated 8 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/cryptolab-cryptolab-default/api/crypto-engine-api/
# ['Crypto Engine APIFREEMIUMByCryptolab', 'Updated 11 days ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/cyberstanc/api/vortex2/
# ['VortexFREEMIUMByCyberstanc', 'Updated 5 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/vdelitz/api/corbado1/
# ['CorbadoFREEByvdelitz', 'Updated vor 5 Monaten', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/salmanakbar264/api/hashing-algorithms-api/
# ['Hashing Algorithms APIFREEBySuleman Akbar', 'Updated 4 months ago', 'CybersecurityPopularity0.2 / 10Latency1,042msService Level0%Health CheckN/A']
# https://rapidapi.com/HybridWebs/api/strong-password-generator2/
# ['Strong Password GeneratorFREEMIUMByHybrid Webs', 'Updated לפני חודשיים', 'CybersecurityPopularity0.1 / 10Latency127,211msService Level0%Health CheckN/A']
# https://rapidapi.com/danlopgom/api/phishunt_io/
# ['phishunt_ioFREEMIUMBydlopez', 'Updated 23 days ago', 'CybersecurityPopularity7.7 / 10Latency376msService Level100%Health Check100%']
# https://rapidapi.com/brandsek-brandsek-default/api/brandsek-breach-check1/
# ['Brandsek Breach CheckFREEMIUMByBrandsek', 'Updated 7 days ago', 'CybersecurityPopularity0.4 / 10Latency21,408msService Level3%Health CheckN/A']
# https://rapidapi.com/DATAHound/api/data-hound/
# ['DATA HoundFREEMIUMByDATAHound', 'Updated 10 months ago', 'CybersecurityPopularity0.1 / 10Latency127,342msService Level0%Health CheckN/A']
# https://rapidapi.com/marianojaozamis/api/email-validator42/
# ['Email ValidatorFREEByMariano Ozamis', 'Updated a year ago', 'CybersecurityPopularity0 / 10Latency36,476msService Level100%Health CheckN/A']
# https://rapidapi.com/aquariuswolf940/api/arespass-free/
# ['AresPass FreeFREEByWolf 940', 'Updated 2 months ago', 'CybersecurityPopularity6.9 / 10Latency134msService Level100%Health CheckN/A']
# https://rapidapi.com/Sauced/api/antipublic/
# ['AntiPublicPAIDBySauced', 'Updated 3달 전', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/Glavier/api/subdomain-finder3/
# ['Subdomain FinderFREEMIUMByGlavier', 'Updated a month ago', 'CybersecurityPopularity8.7 / 10Latency2,458msService Level100%Health CheckN/A']
# https://rapidapi.com/ux-living-lab-ux-living-lab-default/api/dowell-secure-github-repository-api/
# ['Dowell Secure Github Repository APIFREEByUx Living Lab', 'Updated un mese fa', 'CybersecurityPopularity6.1 / 10Latency1,203msService Level100%Health CheckN/A']
# https://rapidapi.com/uniicorniumx/api/apikey01/
# ['apikey01FREEByUniicorniumX', 'Updated a year ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/igorrubinovich/api/websemaphore/
# ['websemaphoreFREEByIgor Rubinovich', 'Updated a month ago', 'CybersecurityHealth Check100%']
# https://rapidapi.com/mungert/api/quantum-ready-check/
# ['Quantum Ready CheckFREEMIUMByMahadeva Cottrell', 'Updated 6 months ago', 'CybersecurityPopularity4.6 / 10Latency309msService Level100%Health CheckN/A']
# https://rapidapi.com/narukaakshat/api/random-password1/
# ['Random PasswordFREEMIUMByprobiex', 'Updated לפני 7 חודשים', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/munsirado-0ktPCF0Rp0w/api/penteston-api/
# ['PENTESTON - APIFREEByRashad Aliyev', 'Updated 4 months ago', 'CybersecurityPopularity7.4 / 10Latency1,679msService Level100%Health CheckN/A']
# https://rapidapi.com/munsirado-0ktPCF0Rp0w/api/port-scanner-api/
# ['Port Scanner APIFREEByRashad Aliyev', 'Updated 5 months ago', 'CybersecurityPopularity0.1 / 10Latency508msService Level100%Health CheckN/A']
# https://rapidapi.com/inutil-inutil-default/api/whatsapp-osint/
# ['Whatsapp OSINTFREEMIUMByinUtil Labs', 'Updated a month ago', 'CybersecurityPopularity8.9 / 10Latency554msService Level100%Health Check100%']
# https://rapidapi.com/tvu-networks-tvu-networks-default/api/user-auth2/
# ['User AuthFREEByTVU networks', 'Updated 3 months ago', 'CybersecurityPopularity8.6 / 10Latency397msService Level100%Health CheckN/A']
# https://rapidapi.com/cavsn/api/crypto-portfolio/
# ['Crypto PortfolioFREEMIUMBycavsn', 'Updated 3 months ago', 'CybersecurityPopularity5.4 / 10Latency2,252msService Level100%Health CheckN/A']
# https://rapidapi.com/vishwaraj/api/waf-api/
# ['WAF APIFREEMIUMByvraj', 'Updated 19 days ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/Whipcode/api/whipcode/
# ['WhipcodeFREEMIUMByWhipcode', 'Updated 7 months ago', 'CybersecurityPopularity6.5 / 10Latency2,001msService Level100%Health CheckN/A']
# https://rapidapi.com/ux-living-lab-ux-living-lab-default/api/dowell-login-api/
# ['Dowell Login APIFREEByUx Living Lab', 'Updated a month ago', 'CybersecurityPopularity5.3 / 10Latency675msService Level100%Health CheckN/A']
# https://rapidapi.com/industrial-data-works-industrial-data-works-default/api/ics-ap-apis/
# ['ICS[AP] APIsFREEMIUMByIndustrial Data Works', 'Updated 2 months ago', 'CybersecurityPopularity8.5 / 10Latency313msService Level100%Health CheckN/A']
# https://rapidapi.com/Sidheeqpallam/api/test19177/
# ['testFREEBySidheeqpallam', 'Updated לפני חודש', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/kidddevs/api/xss-shield/
# ['XSS ShieldFREEMIUMByDakidarts', 'Updated 3 days ago', 'CybersecurityPopularity7.6 / 10Latency952msService Level98%Health Check83%']
# https://rapidapi.com/fptlapwifi/api/demo-project50706/
# ['👋 Demo ProjectFREEByLắp Wifi FPT', 'Updated 4 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/amofficial9192/api/stay-safe-threat-intel-api/
# ['Stay Safe: Threat Intel APIFREEMIUMByCyberInDepth', 'Updated 5 months ago', 'CybersecurityHealth CheckN/A']
# https://rapidapi.com/danlopgom/api/tweetfeed/
# ['TweetFeedFREEBydlopez', 'Updated a day ago', 'CybersecurityPopularity8.2 / 10Latency759msService Level97%Health Check100%']
# https://rapidapi.com/zloadr/api/due-diligence/
# ['Due DiligencePAIDByZloadr', 'Updated 3 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/zloadr/api/airdrop/
# ['AirdropPAIDByZloadr', 'Updated 3 mesi fa', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/zloadr/api/cryptocurrency-token-presales/
# ['Cryptocurrency Token PresalesPAIDByZloadr', 'Updated 3 месяца назад', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/zloadr/api/icos/
# ['ICOsPAIDByZloadr', 'Updated 3 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/zloadr/api/cryptocurrency/
# ['CryptocurrencyPAIDByZloadr', 'Updated 3 месяца назад', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/zloadr/api/cryptocurrency-conversions/
# ['Cryptocurrency ConversionsPAIDByZloadr', 'Updated 3 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/zloadr/api/cryptocurrency-exchanges/
# ['Cryptocurrency ExchangesPAIDByZloadr', 'Updated 3 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/zloadr/api/cryptocurrency-real-time-news/
# ['Cryptocurrency Real Time NewsPAIDByZloadr', 'Updated 3 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/pablogaraguso/api/uuid-v4/
# ['UUID v4FREEMIUMByPablo Garaguso', 'Updated 9 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/vishwaraj/api/hashing-api3/
# ['Hashing apiFREEMIUMByvraj', 'Updated 4 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/pmphobia/api/secure-text-api/
# ['secure-text-apiFREEMIUMByminizymint', 'Updated 8 месяцев назад', 'CryptographyPopularity7.4 / 10Latency829msService Level100%Health CheckN/A']
# https://rapidapi.com/TomJenkins/api/electronic-certificate-verification/
# ['Electronic Certificate VerificationFREEByOleg Sharov', 'Updated a year ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/zloadr/api/nft-metadata-editor/
# ['NFT Metadata EditorFREEMIUMByZloadr', 'Updated 3 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/jwangcn9299/api/web3-api2/
# ['web3 apiFREEByJerry Wang', 'Updated vor 8 Monaten', 'CryptographyPopularity0.2 / 10Latency585msService Level0%Health CheckN/A']
# https://rapidapi.com/cteamapicloud123/api/converter18/
# ['ConverterFREEBy群鼎測試', 'Updated 6 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/vishwaraj/api/encryption-api2/
# ['Encryption APIFREEMIUMByvraj', 'Updated 3 месяца назад', 'CryptographyPopularity5.6 / 10Latency674msService Level100%Health CheckN/A']
# https://rapidapi.com/h1ax8124/api/encode-decode-tool/
# ['Encode/Decode ToolFREEMIUMByHải Nguyễn', 'Updated un mese fa', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/adrian2ross/api/fanfury/
# ['fanfuryFREEByAdrian Ross', 'Updated 9 months ago', 'CryptographyPopularity0 / 10Latency19msService Level0%Health CheckN/A']
# https://rapidapi.com/topapi-topapi-default/api/cryptocurrency-news2/
# ['Cryptocurrency NewsFREEMIUMBytopapi', 'Updated a year ago', 'CryptographyPopularity9.6 / 10Latency673msService Level99%Health CheckN/A']
# https://rapidapi.com/josestg/api/hexsign/
# ['hexsignFREEByJose Alfredo Sitanggang', 'Updated 9 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/reddio-reddio-default/api/reddio-nft-token-and-ipfs/
# ['Reddio NFT, Token and IPFSFREEByReddio', 'Updated לפני שנה', 'CryptographyPopularity8.3 / 10Latency118msService Level99%Health CheckN/A']
# https://rapidapi.com/kumrawath/api/text-qr-generator/
# ['Text QR generatorFREEMIUMByHimanshu Kumrawat', 'Updated a year ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/EymenTakak/api/random-phrase-generator/
# ['Random Phrase GeneratorFREEMIUMByEymenTakak', 'Updated 8 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/nodeworx-nodeworx-default/api/certificate-toolkit/
# ['Certificate ToolkitFREEMIUMByNodeworx', 'Updated a month ago', 'CryptographyHealth Check100%']
# https://rapidapi.com/sumclubfan/api/sum-club/
# ['Sum ClubFREEBysumclubfan', 'Updated 2 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/iftiin-koox-iftiin-koox-default/api/iftiin-crypt/
# ['Iftiin-CryptPAIDByIftiin-api', 'Updated 6 mesi fa', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/contactazguer/api/text-cryptography/
# ['Text cryptographyFREEMIUMByazguer service', 'Updated 5 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/emir12/api/crypto-whale-tracker/
# ['₿ Crypto Whale Tracker 🚀FREEMIUMByCoinSpot', 'Updated 10 mesi fa', 'CryptographyPopularity0.2 / 10Latency275msService Level100%Health CheckN/A']
# https://rapidapi.com/BlakeKaufman/api/bitcoin-wallet/
# ['bitcoin-walletFREEByBlakeKaufman', 'Updated 5 months ago', 'CryptographyPopularity0 / 10Latency26msService Level0%Health CheckN/A']
# https://rapidapi.com/progwhiz1/api/3des-decyption-api/
# ['3Des Decyption APIFREEMIUMByMark Raymond', 'Updated il y a 9 mois', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/progwhiz1/api/pgp-decryption-api/
# ['PGP Decryption APIFREEMIUMByMark Raymond', 'Updated 9 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/sachadee/api/no-intrusive-steganografy/
# ['No Intrusive steganografyFREEMIUMBysachadee', 'Updated 5ヶ月前', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/lucasswartsenburg/api/fun-crypto-ciphers/
# ['Fun Crypto CiphersFREEByLucas Swartsenburg', 'Updated 2 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/starhunter17017/api/digital-currency/
# ['Digital CurrencyPAIDByMichael Bas', 'Updated 10 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/ajenteretecode/api/securityapi1/
# ['securityAPIFREEMIUMByarki code', 'Updated 10 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/kidddevs/api/eea-email-encryption-api/
# ['EEA - Email Encryption APIPAIDByDakidarts', 'Updated 4 months ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/abdalrazak.zk/api/ethereum-keys-generator/
# ['Ethereum Keys GeneratorFREEMIUMByAbdulrezzak Zekiye', 'Updated 1ヶ月前', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/okvipfootball/api/okvip1/
# ['OKVIPFREEByokvipfootball', 'Updated 3달 전', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/darkshadowsdev-darkshadowsdev-default/api/encryptly-hashing-api/
# ['Encryptly Hashing APIFREEMIUMByDarkShadowsDev', 'Updated 3 months ago', 'CryptographyPopularity5.5 / 10Latency21,260msService Level100%Health CheckN/A']
# https://rapidapi.com/lordmukam/api/bybit-p2p-api1/
# ['Bybit p2p APIPAIDByBreak', 'Updated 5 days ago', 'CryptographyPopularity5.6 / 10Latency174msService Level100%Health CheckN/A']
# https://rapidapi.com/rudrai-rudrai-default/api/free-vpn/
# ['Free VPNFREEMIUMByRudrai', 'Updated 2 mesi fa', 'CryptographyPopularity6.9 / 10Latency3,515msService Level50%Health Check100%']
# https://rapidapi.com/narukaakshat/api/url-encoder-decoder/
# ['URL Encoder/DecoderFREEMIUMByprobiex', 'Updated 7 mesi fa', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/admorelli/api/crypto-key-value-store/
# ['Crypto Key Value StoreFREEMIUMByadmorelli', 'Updated a year ago', 'CryptographyHealth CheckN/A']
# https://rapidapi.com/Murad123/api/moviesverse1/
# ['MoviesVerseFREEBySardar_Ali_Murad', 'Updated 2 days ago', 'MoviesPopularity9.7 / 10Latency1,315msService Level100%Health CheckN/A']
# https://rapidapi.com/dotero27022001/api/movies-app1/
# ['Movies AppFREEMIUMByJesus Cotito', 'Updated 4 months ago', 'MoviesPopularity8.9 / 10Latency2,271msService Level99%Health CheckN/A']
# https://rapidapi.com/ellahTestingTool/api/daily-ovrll-0822202141203/
# ['DAILY OVRLL 0822202141203FREEByEllah Toren', 'Updated vor einem Jahr', 'MoviesPopularity8.2 / 10Latency703msService Level100%Health CheckN/A']
# https://rapidapi.com/Glavier/api/imdb146/
# ['IMDbFREEMIUMByGlavier', 'Updated 13 days ago', 'MoviesPopularity9.6 / 10Latency1,473msService Level100%Health CheckN/A']
# https://rapidapi.com/starcrasher54/api/upcoming-anime/
# ['Upcoming AnimePAIDBylochi k', 'Updated 3 दिन पहले', 'MoviesPopularity6.9 / 10Latency948msService Level87%Health Check57%']
# https://rapidapi.com/16231108/api/getpopular1/
# ['getpopularFREEBy16231108', 'Updated a year ago', 'MoviesPopularity0.3 / 10Latency127,284msService Level0%Health CheckN/A']
# https://rapidapi.com/KASO/api/where-can-i-watch1/
# ['Where can I watchFREEMIUMByKASO', 'Updated il y a un an', 'MoviesPopularity8.6 / 10Latency2,098msService Level100%Health CheckN/A']
# https://rapidapi.com/SAdrian/api/moviesdatabase/
# ['MoviesDatabaseFREEMIUMByAdriano Massimo', 'Updated 3 months ago', 'MoviesPopularity9.9 / 10Latency2,696msService Level98%Health CheckN/A']
# https://rapidapi.com/abirbhattacharya82/api/abir82-bollywood-recommendations/
# ['Abir82 Bollywood RecommendationsFREEByAbir Bhattacharya', 'Updated a year ago', 'MoviesPopularity9.2 / 10Latency398msService Level100%Health CheckN/A']
# https://rapidapi.com/ellahTestingTool/api/daily-ovrll-0822202130837/
# ['DAILY OVRLL 0822202130837FREEByEllah Toren', 'Updated לפני שנה', 'MoviesPopularity6.9 / 10Latency559msService Level100%Health CheckN/A']
# https://rapidapi.com/flashbomberapp/api/imdb-search2/
# ['IMDB SearchFREEMIUMByFlash Bomber', 'Updated 3 months ago', 'MoviesPopularity9 / 10Latency518msService Level100%Health CheckN/A']
# https://rapidapi.com/amrelrafie/api/movies-tv-shows-database/
# ['Movies Tv Shows DatabaseFREEMIUMByTechView', 'Updated il y a un an', 'MoviesPopularity9.6 / 10Latency520msService Level100%Health CheckN/A']
# https://rapidapi.com/skrebl/api/tip-for-movie/
# ['Tip for movieFREEMIUMByskrebl', 'Updated un anno fa', 'MoviesPopularity5.3 / 10Latency2,495msService Level100%Health CheckN/A']
# https://rapidapi.com/myritebook-myritebook-default/api/myritebook/
# ['MyritebookFREEByMyritebook', 'Updated год назад', 'MoviesPopularity7.9 / 10Latency5,614msService Level100%Health CheckN/A']
# https://rapidapi.com/netostbatista-8PFB2-57zTu/api/tvshow/
# ['TVShowFREEMIUMByNeto Batista', 'Updated 2 days ago', 'MoviesPopularity8.6 / 10Latency848msService Level100%Health Check100%']
# https://rapidapi.com/louislefebure9/api/star-wars-characters/
# ['Star Wars CharactersFREEMIUMByLouis Lefebure', 'Updated a year ago', 'MoviesPopularity8.7 / 10Latency734msService Level100%Health CheckN/A']
# https://rapidapi.com/animeslayerquiz/api/similar-movies/
# ['Similar MoviesFREEMIUMByMedcode', 'Updated a year ago', 'MoviesPopularity8.7 / 10Latency3,223msService Level81%Health CheckN/A']
# https://rapidapi.com/yaminshelly/api/star-wars7/
# ['Star-WarsFREEByשלי רביבו', 'Updated a year ago', 'MoviesPopularity0.3 / 10Latency785msService Level100%Health CheckN/A']
# https://rapidapi.com/mahamcodes/api/movies-api5/
# ['Movies APIFREEByMaham Codes', 'Updated a year ago', 'MoviesPopularity0.4 / 10Latency676msService Level100%Health CheckN/A']
# https://rapidapi.com/ellahTestingTool/api/daily-ovrll-0822202143542/
# ['DAILY OVRLL 0822202143542FREEByEllah Toren', 'Updated a year ago', 'MoviesPopularity6.2 / 10Latency769msService Level100%Health CheckN/A']
# https://rapidapi.com/diikagnteng-McDOF1W7i07/api/vod1/
# ['VODFREEByhandika pratama', 'Updated a year ago', 'MoviesPopularity0.1 / 10Latency10msService Level0%Health CheckN/A']
# https://rapidapi.com/AMINE1921/api/top-10-movies-of-the-day/
# ['TOP 10 movies of the dayFREEMIUMByAMINE1921', 'Updated il y a un an', 'MoviesPopularity0.1 / 10Latency167msService Level100%Health CheckN/A']
# https://rapidapi.com/andrewsapw/api/film-ru/
# ['Информация о кино (film.ru)FREEMIUMByAndrew S', 'Updated il y a un an', 'MoviesHealth CheckN/A']
# https://rapidapi.com/gowatch/api/gowatch/
# ['GoWATCHFREEMIUMBygowatch', 'Updated a year ago', 'MoviesPopularity0.4 / 10Latency414msService Level100%Health CheckN/A']
# https://rapidapi.com/movie-of-the-night-movie-of-the-night-default/api/streaming-availability/
# ['Streaming AvailabilityFREEMIUMVerified✓ByMovie of the Night', 'Updated 2 months ago', 'MoviesPopularity9.9 / 10Latency486msService Level100%Health CheckN/A']
# https://rapidapi.com/rahullalraghav/api/movies157/
# ['MoviesFREEByRahul Lal', 'Updated a year ago', 'MoviesPopularity0.1 / 10Latency42,591msService Level0%Health CheckN/A']
# https://rapidapi.com/jpbermoy/api/movie-search-and-listing-api1/
# ['Movie Search and Listing APIFREEMIUMByMUSIC EXCLUSIVE', 'Updated 3 months ago', 'MoviesPopularity6.5 / 10Latency1,275msService Level100%Health CheckN/A']
# https://rapidapi.com/SAdrian/api/moviesminidatabase/
# ['MoviesMiniDatabaseFREEMIUMByAdriano Massimo', 'Updated 3 months ago', 'MoviesPopularity9.9 / 10Latency989msService Level100%Health CheckN/A']
# https://rapidapi.com/mycoding73-29RJKzwz_49/api/asiandramas-api-with-watching-link/
# ['AsianDramas API with Watching LinkFREEMIUMByCoding Coder', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/arvitaly/api/films2/
# ['FFilmsFREEByVitaly', 'Updated a year ago', 'MoviesPopularity5.3 / 10Latency850msService Level100%Health CheckN/A']
# https://rapidapi.com/standingapi-standingapi-default/api/1mdb-data-searching/
# ['1MDB Data SearchingFREEMIUMByStandingAPI', 'Updated a year ago', 'MoviesPopularity0.2 / 10Latency65msService Level0%Health CheckN/A']
# https://rapidapi.com/ExoWatts/api/chuck-norris-facts/
# ['Chuck Norris FactsPAIDByExoWatts', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/felsefice/api/apibreakingbad/
# ['apibreakingbadFREEByfelsefice', 'Updated 2 months ago', 'MoviesPopularity6.6 / 10Latency845msService Level100%Health CheckN/A']
# https://rapidapi.com/sniperdevil/api/torrent-scrapper-api/
# ['torrent-scrapper-apiFREEMIUMBysniperdevil', 'Updated a year ago', 'MoviesPopularity0.1 / 10Latency382msService Level100%Health CheckN/A']
# https://rapidapi.com/dockerizator/api/flicksnlinks/
# ['FlicksNLinksFREEMIUMByDockerizator', 'Updated 22 days ago', 'MoviesPopularity7.9 / 10Latency46,300msService Level69%Health CheckN/A']
# https://rapidapi.com/contactazguer/api/movie-database-imdb/
# ['Movie Database IMDbFREEMIUMByazguer service', 'Updated 2 months ago', 'MoviesPopularity5.3 / 10Latency2,312msService Level100%Health CheckN/A']
# https://rapidapi.com/selcukguler0/api/one-piece2/
# ['One PieceFREEMIUMByselcukguler0', 'Updated a year ago', 'MoviesPopularity9.1 / 10Latency1,594msService Level100%Health CheckN/A']
# https://rapidapi.com/amandapakalniskyte/api/movies-api6/
# ['Movies APIFREEMIUMByAmanda Pakalniškytė', 'Updated a year ago', 'MoviesPopularity6.2 / 10Latency160,522msService Level100%Health CheckN/A']
# https://rapidapi.com/Mangsud/api/paxapi/
# ['PaxApiFREEByMangsud', 'Updated 일 년 전', 'MoviesPopularity4.9 / 10Latency720msService Level100%Health CheckN/A']
# https://rapidapi.com/minthura635-_V0ntJJpmDT/api/razorcloud-xtream1/
# ['Razorcloud XtreamFREEMIUMByMM Tech Channel', 'Updated a year ago', 'MoviesPopularity0.2 / 10Latency215msService Level67%Health CheckN/A']
# https://rapidapi.com/Glavier/api/netflix54/
# ['NetflixFREEMIUMByGlavier', 'Updated 4 months ago', 'MoviesPopularity9.6 / 10Latency1,981msService Level100%Health CheckN/A']
# https://rapidapi.com/avya1988112008/api/movies-and-tv-database/
# ['Movies and Tv DatabasePAIDByavdya Batch007', 'Updated il y a un an', 'MoviesHealth CheckN/A']
# https://rapidapi.com/mikechen342/api/movie-tv-music-search-and-download/
# ['Movie, TV, music search and downloadFREEMIUMByMythical Frog', 'Updated 5 months ago', 'MoviesPopularity8.8 / 10Latency1,000msService Level100%Health CheckN/A']
# https://rapidapi.com/pierregoutheraud/api/movies-ratings2/
# ['Movies RatingsFREEMIUMByPierre Gouthéraud', 'Updated 3 months ago', 'MoviesPopularity9.5 / 10Latency2,577msService Level99%Health CheckN/A']
# https://rapidapi.com/apiwhiz/api/game-of-thrones-quotes/
# ['Game of Thrones QuotesFREEMIUMByapi whiz', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/yassinezaza20/api/imdb-top-100-movies1/
# ['IMDb top 100 moviesFREEMIUMByAPI Solutions', 'Updated vor 6 Monaten', 'MoviesPopularity9.1 / 10Latency682msService Level100%Health CheckN/A']
# https://rapidapi.com/kvngfawaz-fX53a8DV5tH/api/latest-movies/
# ['Latest MoviesFREEMIUMByFawaz Animashaun', 'Updated a year ago', 'MoviesPopularity0.3 / 10Latency352msService Level0%Health CheckN/A']
# https://rapidapi.com/WenAP/api/aws-serverless-challenge/
# ['aws-serverless-challengeFREEByWenAP', 'Updated il y a 7 mois', 'MoviesHealth CheckN/A']
# https://rapidapi.com/unluckychild/api/aiom-db-all-in-one-movie-database/
# ['AIOM DB - All In One Movie DatabaseFREEMIUMByerik parker', 'Updated לפני שנה', 'MoviesHealth CheckN/A']
# https://rapidapi.com/esmat10.niazi/api/movieera-101/
# ['Movieera-101FREEMIUMByEsmatullah niazi', 'Updated a year ago', 'MoviesPopularity0.2 / 10Latency175msService Level100%Health CheckN/A']
# https://rapidapi.com/sshanbond/api/movies-shows-subtitles-search1/
# ['Movies/Shows Subtitles SearchFREEBydev6', 'Updated a year ago', 'MoviesPopularity0.3 / 10Latency347msService Level100%Health CheckN/A']
# https://rapidapi.com/prajyu2003/api/potter-spells/
# ['Potter SpellsFREEMIUMByPrajyu M S', 'Updated a year ago', 'MoviesPopularity0.1 / 10Latency116msService Level100%Health CheckN/A']
# https://rapidapi.com/bocahmyanmar/api/apikiki/
# ['apikikiFREEByBocah Myanmar', 'Updated एक वर्ष पहले', 'MoviesPopularity0.1 / 10Latency147msService Level0%Health CheckN/A']
# https://rapidapi.com/leahdaypeters4411/api/filmquestions/
# ['filmquestionsFREEMIUMByleahdaypeters4411', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/laminesaadi92-RXm-MnhKQy/api/netflix26/
# ['netflixFREEByMovieS L92', 'Updated год назад', 'MoviesPopularity7.9 / 10Latency554msService Level100%Health CheckN/A']
# https://rapidapi.com/abdonvaldez705/api/movies-quest/
# ['Movies QuestFREEMIUMByabdonvaldez705', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/hendrahima1-0PV5OBAUoqB/api/james-bond-movie-series-data/
# ['James Bond Movie Series DataFREEMIUMByHenHim', 'Updated a year ago', 'MoviesPopularity0.1 / 10Latency507msService Level100%Health CheckN/A']
# https://rapidapi.com/elisbushaj2/api/movies-api14/
# ['Movies APIFREEMIUMByElis', 'Updated a month ago', 'MoviesPopularity9.7 / 10Latency768msService Level95%Health CheckN/A']
# https://rapidapi.com/patriciaatrindade/api/movies115/
# ['MoviesFREEBypatriciaatrindade', 'Updated a year ago', 'MoviesPopularity0 / 10Latency114msService Level100%Health CheckN/A']
# https://rapidapi.com/janetmsrian12253/api/data-movies/
# ['Data MoviesFREEMIUMByjanetmsrian12253', 'Updated hace un año', 'MoviesHealth CheckN/A']
# https://rapidapi.com/insanemedia-insanemedia-default/api/youtube-video-download/
# ['youtube video downloadFREEByinsanemedia', 'Updated एक वर्ष पहले', 'MoviesHealth CheckN/A']
# https://rapidapi.com/mack06/api/filmaffinity-unofficial/
# ['filmaffinity unofficialFREEBymack06', 'Updated a year ago', 'MoviesPopularity8.7 / 10Latency3,250msService Level100%Health CheckN/A']
# https://rapidapi.com/deji12/api/protontv/
# ['ProtonTvFREEBydeji12', 'Updated לפני 8 חודשים', 'MoviesPopularity6.8 / 10Latency645msService Level100%Health CheckN/A']
# https://rapidapi.com/prasadpadala2005/api/demo-project41095/
# ['👋 Demo ProjectFREEByPrasad Padala', 'Updated il y a 6 mois', 'MoviesPopularity4.7 / 10Latency532msService Level100%Health CheckN/A']
# https://rapidapi.com/sparrowxdexe/api/imdb207/
# ['IMDbFREEMIUMBySparrowXD', 'Updated 10 giorni fa', 'MoviesPopularity8.9 / 10Latency2,875msService Level100%Health Check100%']
# https://rapidapi.com/dhbeckbessinger-nPureuw0-k7/api/rapidtest3/
# ['RapidTestFREEByRedwaltz Gaming', 'Updated a year ago', 'MoviesPopularity5.1 / 10Latency546msService Level100%Health CheckN/A']
# https://rapidapi.com/oubenhamouy10/api/best-of-movies/
# ['Best of MoviesFREEMIUMByYoussef Oubenhamou', 'Updated 2 months ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/ketuman333-ZEuCxBwXq0v/api/moviehut-random-movie/
# ['MovieHut - Random MovieFREEByKetuman Vishwakarma', 'Updated לפני שנה', 'MoviesPopularity0.2 / 10Latency631msService Level100%Health CheckN/A']
# https://rapidapi.com/mdwit0r/api/knopoisk_dev_api/
# ['knopoisk_dev_apiFREEByElliot Alderson', 'Updated a year ago', 'MoviesPopularity6.9 / 10Latency1,041msService Level100%Health CheckN/A']
# https://rapidapi.com/ellahTestingTool/api/daily-ovrll-0822202130334/
# ['DAILY OVRLL 0822202130334FREEByEllah Toren', 'Updated il y a un an', 'MoviesPopularity6.3 / 10Latency678msService Level100%Health CheckN/A']
# https://rapidapi.com/anshuldagar9/api/porn-links/
# ['Porn LinksFREEMIUMByIronman9799', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/ellahTestingTool/api/daily-ovrll-0822202140642/
# ['DAILY OVRLL 0822202140642FREEByEllah Toren', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/belchiorarkad-FqvHs2EDOtP/api/youtube-downloader19/
# ['Youtube DownloaderFREEMIUMByPinto Studio', 'Updated hace 7 meses', 'MoviesHealth CheckN/A']
# https://rapidapi.com/amrashebo09-r8j-JEnjktA/api/movie-and-tv-show-api/
# ['Movie and TV show APIPAIDByAmr Ashebo', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/sechno-sechno-default/api/latest-anime-api/
# ['Latest Anime APIFREEMIUMBySechno', 'Updated 4 months ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/SheMortal/api/campertrailerpro/
# ['campertrailerproFREEByShe_Mortal', 'Updated a year ago', 'MoviesPopularity0.1 / 10Latency11msService Level0%Health CheckN/A']
# https://rapidapi.com/jakash1997/api/advanced-movie-search/
# ['Advanced Movie SearchFREEMIUMVerified✓ByAkash Joshi', 'Updated a year ago', 'MoviesPopularity9.5 / 10Latency430msService Level100%Health CheckN/A']
# https://rapidapi.com/lukerhodri-qXjCQuaRNKg/api/highest-grossing-movies/
# ['Highest Grossing MoviesFREEMIUMByDojoDanger', 'Updated год назад', 'MoviesHealth CheckN/A']
# https://rapidapi.com/soyamchinglemba/api/imdb_api4/
# ['IMDB_APIFREEMIUMBySoyam Chinglemba', 'Updated 8 months ago', 'MoviesPopularity8.9 / 10Latency800msService Level100%Health CheckN/A']
# https://rapidapi.com/cmwamba058-_Sq9hGXi1E/api/animes3/
# ['animesFREEMIUMBychristopher mwamba', 'Updated a year ago', 'MoviesPopularity0.1 / 10Latency1,021msService Level100%Health CheckN/A']
# https://rapidapi.com/yaminshelly/api/my-movies2/
# ['my-moviesFREEByשלי רביבו', 'Updated 일 년 전', 'MoviesHealth CheckN/A']
# https://rapidapi.com/standingapi-standingapi-default/api/moviesdb5/
# ['MoviesDBFREEMIUMByStandingAPI', 'Updated a year ago', 'MoviesPopularity1.8 / 10Latency254msService Level29%Health CheckN/A']
# https://rapidapi.com/dotero27022001/api/global-movies-api-hub/
# ['Global Movies Api HubFREEMIUMByJesus Cotito', 'Updated 5 mesi fa', 'MoviesPopularity7.4 / 10Latency1,322msService Level100%Health CheckN/A']
# https://rapidapi.com/rur209-fl23Nrvhxii/api/movie-and-tv-shows-quotes/
# ['Movie and TV shows QuotesFREEMIUMByRohith Ravishankar', 'Updated 10 months ago', 'MoviesPopularity8.4 / 10Latency1,199msService Level100%Health CheckN/A']
# https://rapidapi.com/jonhsonle-jonhsonle-default/api/thanh-nguyen/
# ['thanh nguyenFREEByjonhsonle', 'Updated a year ago', 'MoviesPopularity0.1 / 10Latency1,503msService Level100%Health CheckN/A']
# https://rapidapi.com/ellahTestingTool/api/daily-ovrll-0822202130418/
# ['DAILY OVRLL 0822202130418FREEByEllah Toren', 'Updated a year ago', 'MoviesPopularity5.4 / 10Latency1,184msService Level100%Health CheckN/A']
# https://rapidapi.com/ellahTestingTool/api/daily-ovrll-0822202124848/
# ['DAILY OVRLL 0822202124848FREEByEllah Toren', 'Updated un anno fa', 'MoviesPopularity6.1 / 10Latency835msService Level100%Health CheckN/A']
# https://rapidapi.com/bhaskarreddyakepati/api/ott-release-updates/
# ['OTT Release UpdatesFREEMIUMByVijay Reddy', 'Updated एक वर्ष पहले', 'MoviesHealth CheckN/A']
# https://rapidapi.com/phuongnam131201.nnnpn/api/movie-group-3/
# ['Movie Group 3FREEByNam Nguyễn Phương', 'Updated a year ago', 'MoviesPopularity0.2 / 10Latency11msService Level0%Health CheckN/A']
# https://rapidapi.com/TODASApps/api/movies-and-tv-shows-streaming/
# ['Movies and TV Shows StreamingFREEMIUMByTODAS Apps', 'Updated 16時間前', 'MoviesPopularity4.7 / 10Latency325msService Level100%Health CheckN/A']
# https://rapidapi.com/gox-ai-gox-ai-default/api/ott-details/
# ['OTT detailsFREEMIUMByGoX-ai', 'Updated a year ago', 'MoviesPopularity9.7 / 10Latency344msService Level100%Health CheckN/A']
# https://rapidapi.com/belchiorarkad-FqvHs2EDOtP/api/movie-database21/
# ['Movie DatabaseFREEMIUMByPinto Studio', 'Updated месяц назад', 'MoviesPopularity5.2 / 10Latency2,434msService Level100%Health CheckN/A']
# https://rapidapi.com/brian.rofiq/api/anime-db/
# ['Anime DBFREEMIUMByBrianRofiq', 'Updated 8 months ago', 'MoviesPopularity9.6 / 10Latency480msService Level100%Health CheckN/A']
# https://rapidapi.com/rasiqueira/api/netflix-unofficial/
# ['Netflix UnofficialFREEMIUMByencod', 'Updated एक वर्ष पहले', 'MoviesPopularity0.3 / 10Latency126msService Level0%Health CheckN/A']
# https://rapidapi.com/manoharmohanta/api/reeltorrent/
# ['ReelTorrentFREEMIUMBySunglade Digital Solutions', 'Updated a year ago', 'MoviesHealth CheckN/A']
# https://rapidapi.com/vuesdata/api/indeed-jobs-api-sweden/
# ['Indeed Jobs API - SwedenFREEMIUMByVues Data', 'Updated 10 mesi fa', 'JobsPopularity8.5 / 10Latency18,881msService Level100%Health CheckN/A']
# https://rapidapi.com/qurazor1/api/remoote-job-search1/
# ['Remoote Job SearchFREEMIUMByMikhail Astashkevich', 'Updated a month ago', 'JobsPopularity8.4 / 10Latency1,584msService Level100%Health CheckN/A']
# https://rapidapi.com/elshadaghazade/api/upwork-jobs-api1/
# ['Upwork Jobs APIFREEMIUMByElşad Ağazadə', 'Updated a year ago', 'JobsPopularity0 / 10Latency10,031msService Level0%Health CheckN/A']
# https://rapidapi.com/techmap-io-techmap-io-default/api/daily-international-job-postings/
# ['Daily International Job PostingsFREEMIUMByTechmap-io', 'Updated 2ヶ月前', 'JobsPopularity8.3 / 10Latency1,962msService Level100%Health CheckN/A']
# https://rapidapi.com/hyconsconstruction/api/demo-project46763/
# ['👋 Demo ProjectFREEByConstruction Hycons', 'Updated 5 months ago', 'JobsPopularity7.3 / 10Latency709msService Level100%Health CheckN/A']
# https://rapidapi.com/hidekazushidara/api/jobs37/
# ['JobsPAIDByHidekazu Shidara', 'Updated 6 months ago', 'JobsHealth CheckN/A']
# https://rapidapi.com/kazamos/api/remote-jobs-api/
# ['Remote Jobs APIFREEMIUMBykazamos', 'Updated 10 месяцев назад', 'JobsPopularity9 / 10Latency603msService Level100%Health CheckN/A']
# https://rapidapi.com/vuesdata/api/indeed-jobs-api-denmark/
# ['Indeed Jobs API - DenmarkFREEMIUMByVues Data', 'Updated 2 months ago', 'JobsPopularity6.5 / 10Latency5,503msService Level100%Health CheckN/A']
# https://rapidapi.com/vuesdata/api/indeed-jobs-api-finland/
# ['Indeed Jobs API - FinlandFREEMIUMByVues Data', 'Updated 10 months ago', 'JobsPopularity8.2 / 10Latency26,829msService Level100%Health CheckN/A']
# https://rapidapi.com/bebity-bebity-default/api/linkedin-jobs-scraper-api/
# ['Linkedin jobs scraper APIFREEMIUMByBebity.io', 'Updated 4 months ago', 'JobsPopularity9.7 / 10Latency42,766msService Level68%Health CheckN/A']
# https://rapidapi.com/maurobonfietti/api/open-to-work-remote-api/
# ['Open To Work Remote APIPAIDBymaurobonfietti', 'Updated 15 days ago', 'JobsPopularity8.6 / 10Latency1,185msService Level100%Health CheckN/A']
# https://rapidapi.com/mserafimovski87/api/jobspider-resumes/
# ['Jobspider ResumesFREEMIUMByMiki Serafimovski', 'Updated hace 8 meses', 'JobsPopularity0.1 / 10Latency1,373msService Level0%Health CheckN/A']
# https://rapidapi.com/adrienpelletierlaroche/api/nyc-jobs/
# ['NYC JobsFREEMIUMByFuryHavings', 'Updated 4 months ago', 'JobsHealth CheckN/A']
# https://rapidapi.com/jobwiz-jobwiz-default/api/job-descriptions-api/
# ['Job Descriptions APIFREEMIUMByJobWiz', 'Updated a month ago', 'JobsPopularity7.9 / 10Latency3,475msService Level100%Health CheckN/A']
# https://rapidapi.com/it-engineering-solutions-it-engineering-solutions-default/api/upwork-api2/
# ['Upwork APIPAIDByIT Engineering Solutions', 'Updated 7日前', 'JobsPopularity8.1 / 10Latency900msService Level96%Health CheckN/A']
# https://rapidapi.com/jobwiz-jobwiz-default/api/job-search-api1/
# ['Job Search APIFREEMIUMByJobWiz', 'Updated 3달 전', 'JobsPopularity9.3 / 10Latency8,704msService Level99%Health CheckN/A']
# https://rapidapi.com/bytebricks-bytebricks-default/api/bytebricks/
# ['ByteBricksFREEMIUMByByteBricks Job API', 'Updated 4 months ago', 'JobsHealth CheckN/A']
# https://rapidapi.com/imploms/api/ai-resume-generator/
# ['AI Resume GeneratorFREEMIUMBy2hearted', 'Updated 20 days ago', 'JobsPopularity8.5 / 10Latency3,011msService Level100%Health CheckN/A']
# https://rapidapi.com/jobicy-jobicy-default/api/jobicy/
# ['JobicyFREEMIUMByJobicy', 'Updated 10 days ago', 'JobsPopularity8.2 / 10Latency661msService Level100%Health Check100%']
# https://rapidapi.com/Pat92/api/jobs-api14/
# ['Jobs APIFREEMIUMByPatrick Hettich', 'Updated एक महीने पहले', 'JobsPopularity9.4 / 10Latency871msService Level100%Health Check100%']
# https://rapidapi.com/bareq/api/remote-jobs-api1/
# ['Remote jobs APIFREEMIUMBybareq', 'Updated 6 days ago', 'JobsPopularity7.7 / 10Latency2,111msService Level100%Health Check100%']
# https://rapidapi.com/pritiyadav888/api/random-gradient-resume-template-generator/
# ['Random Gradient Resume Template GeneratorFREEBypriti yadav', 'Updated לפני 9 חודשים', 'JobsPopularity0.3 / 10Latency443msService Level100%Health CheckN/A']
# https://rapidapi.com/mustacy/api/linkedin-jobs-python-developer/
# ['Linkedin Jobs: Python DeveloperPAIDBymustacy', 'Updated hace 8 meses', 'JobsHealth CheckN/A']
# https://rapidapi.com/vuesdata/api/indeed-jobs-api/
# ['Indeed Jobs APIFREEMIUMByVues Data', 'Updated 10 months ago', 'JobsPopularity9.3 / 10Latency3,912msService Level100%Health CheckN/A']
# https://rapidapi.com/enegaeruapi/api/enegaeru-home-energy-usage-optimizer/
# ['Enegaeru Home Energy Usage OptimizerPAIDByenegaeruapi', 'Updated hace 2 años', 'EnergyHealth CheckN/A']
# https://rapidapi.com/enegaeruapi/api/enegaeru-home-energy-plan-simulator/
# ['Enegaeru Home Energy Plan SimulatorPAIDByenegaeruapi', 'Updated 2 years ago', 'EnergyHealth CheckN/A']
# https://rapidapi.com/panagiotistzimis/api/fuels-live/
# ['Fuels LiveFREEMIUMByPanagiotis Tzimis', 'Updated 2 years ago', 'EnergyPopularity0 / 10Latency34msService Level100%Health CheckN/A']
# https://rapidapi.com/adrienpelletierlaroche/api/electric-vehicle-data2/
# ['Electric Vehicle DataFREEMIUMByFuryHavings', 'Updated hace 4 meses', 'EnergyPopularity8.1 / 10Latency2,522msService Level98%Health CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/electricity-carbon-footprint-germany/
# ['Electricity Carbon Footprint GermanyFREEMIUMBySTROMDAO', 'Updated 2 years ago', 'EnergyPopularity7.7 / 10Latency358msService Level100%Health CheckN/A']
# https://rapidapi.com/rsafaya/api/edrv-ev-charging/
# ['eDRV EV ChargingFREEByRupul Safaya', 'Updated 2 years ago', 'EnergyPopularity0.3 / 10Latency974msService Level100%Health CheckN/A']
# https://rapidapi.com/tango-api-tango-api-default/api/daily-fuel-price-india1/
# ['Daily Fuel Price IndiaFREEMIUMByTango Api', 'Updated 9 months ago', 'EnergyPopularity6.7 / 10Latency268msService Level100%Health CheckN/A']
# https://rapidapi.com/miesolavi/api/co2-emissions/
# ['CO2 EmissionsFREEMIUMBymiesolavi', 'Updated 4 months ago', 'EnergyHealth CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/strom-quittung/
# ['Strom-QuittungFREEMIUMBySTROMDAO', 'Updated 2 years ago', 'EnergyPopularity0.1 / 10Latency691msService Level0%Health CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/warmepumpen-steuerungssignal/
# ['Wärmepumpen SteuerungssignalFREEMIUMBySTROMDAO', 'Updated a year ago', 'EnergyHealth CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/solarenergyprediction/
# ['SolarEnergyPredictionFREEMIUMBySTROMDAO', 'Updated a year ago', 'EnergyPopularity0.4 / 10Latency25,881msService Level6%Health CheckN/A']
# https://rapidapi.com/esproject-esproject-default/api/pln-name-api/
# ['PLN Name APIFREEMIUMByesproject', 'Updated 2 महीने पहले', 'EnergyPopularity5.7 / 10Latency911msService Level100%Health CheckN/A']
# https://rapidapi.com/mariano-S5TXhNSEEEK/api/uruguay-fuels-api/
# ['Uruguay Fuels APIFREEMIUMByMariano B.', 'Updated a year ago', 'EnergyHealth CheckN/A']
# https://rapidapi.com/buildingviz-buildingviz-default/api/caiso/
# ['CAISOFREEMIUMByBuildingViz', 'Updated a year ago', 'EnergyPopularity8.3 / 10Latency7,432msService Level81%Health CheckN/A']
# https://rapidapi.com/contacto.siaho/api/oil-well-directional-drilling-survey-calculations/
# ['Oil Well Directional Drilling Survey CalculationsPAIDBysiaho portal', 'Updated 2 years ago', 'EnergyPopularity6.7 / 10Latency138msService Level97%Health CheckN/A']
# https://rapidapi.com/adrienpelletierlaroche/api/electric-vehicle8/
# ['Electric VehicleFREEMIUMByFuryHavings', 'Updated 4 months ago', 'EnergyPopularity0 / 10Latency333msService Level0%Health CheckN/A']
# https://rapidapi.com/saget/api/cbecs/
# ['CBECSFREEMIUMBysage-t', 'Updated год назад', 'EnergyHealth CheckN/A']
# https://rapidapi.com/turvas/api/energy-optimizer/
# ['energy OptimizerFREEMIUMByturvas', 'Updated 17 giorni fa', 'EnergyHealth Check0%']
# https://rapidapi.com/muskaanmaheshwari02/api/daily-quote4/
# ['Daily QuoteFREEByMuskan Maheshwari', 'Updated 9 days ago', 'EnergyPopularity6.4 / 10Latency1,731msService Level100%Health CheckN/A']
# https://rapidapi.com/deiyam88/api/proclima/
# ['proclimaFREEByDeimer Valencia', 'Updated vor 2 Jahren', 'EnergyPopularity0 / 10Latency58msService Level100%Health CheckN/A']
# https://rapidapi.com/blueman/api/mamarketa/
# ['mamarketaFREEByalifree', 'Updated vor 2 Jahren', 'EnergyHealth CheckN/A']
# https://rapidapi.com/kevinjimyy-fIctOln0gSO/api/oil-and-gas-renewable-energy-news/
# ['Oil and Gas/ Renewable Energy NewsFREEMIUMByKevin Jim', 'Updated 6 months ago', 'EnergyPopularity0 / 10Latency294msService Level0%Health CheckN/A']
# https://rapidapi.com/enode-enode-default/api/enode-api/
# ['Enode APIFREEByEnode', 'Updated 1年前', 'EnergyHealth CheckN/A']
# https://rapidapi.com/t0rkh/api/german-gasstation-prices/
# ['German Gasstation PricesPAIDByThorsten Hinz', 'Updated 2 years ago', 'EnergyHealth CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/standardlastprofil-rechner/
# ['Standardlastprofil-RechnerFREEMIUMBySTROMDAO', 'Updated il y a un an', 'EnergyPopularity7.7 / 10Latency596msService Level99%Health CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/corrently/
# ['CorrentlyFREEMIUMBySTROMDAO', 'Updated a year ago', 'EnergyHealth CheckN/A']
# https://rapidapi.com/karthi20012002/api/indian-fuel/
# ['INDIAN FUELFREEMIUMByKARTHIKEYAN THIRUMALAISAMY', 'Updated 5 days ago', 'EnergyPopularity7.4 / 10Latency2,731msService Level100%Health Check100%']
# https://rapidapi.com/hafitkode-iLnzlb6I0uv/api/motivation-api1/
# ['Motivation-apiFREEMIUMBynickname_ Day', 'Updated 2 years ago', 'EnergyHealth CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/co2-offset/
# ['CO2 OffsetPAIDBySTROMDAO', 'Updated a year ago', 'EnergyPopularity2.1 / 10Latency2,479msService Level19%Health CheckN/A']
# https://rapidapi.com/olivegaea/api/olivegaea/
# ['OliveGaeaFREEByolivegaea', 'Updated hace un año', 'EnergyPopularity0.1 / 10Latency473msService Level100%Health CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/marktdaten-deutschland/
# ['Marktdaten DeutschlandFREEMIUMBySTROMDAO', 'Updated hace un año', 'EnergyPopularity9.1 / 10Latency428msService Level100%Health CheckN/A']
# https://rapidapi.com/stromdao-stromdao-default/api/ecoweather/
# ['ecoweatherFREEMIUMBySTROMDAO', 'Updated a year ago', 'EnergyPopularity8.6 / 10Latency4,684msService Level81%Health CheckN/A']
# https://rapidapi.com/nemy-nemy/api/nemy/
# ['nemyFREEMIUMBynemy', 'Updated un anno fa', 'EnergyPopularity8.7 / 10Latency1,482msService Level100%Health CheckN/A']
# https://rapidapi.com/mi8y-mi8y-default/api/daily-petrol-diesel-lpg-cng-fuel-prices-in-india/
# ...
# https://rapidapi.com/fgribreau/api/time-series-anomaly-detector-tsad/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/ganeshpark/api/jsonremovelnulls/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/solcast/api/solcast/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/emailhippo/api/cash-parked-domain-detector/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/alastechnology/api/cadastral-situation-of-the-brazilian-cpf-numbers/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/Hunter130999/api/apinew/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/lodbujana75/api/menya/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/gamerxnewchanel/api/chranimse/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/rockapis-rockapis-default/api/google-play-store-scraper-api/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/gehad4195/api/siren2url1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/ApfelPresse/api/penny-online-market/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/scamadviser1/api/scamadviser1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/ushinohama966/api/japan-info1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/lazenifofana/api/business-scams-fraud-prevention-api/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/iptv-live/api/iptv-live-iptv-playlists/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/janjiczoran23/api/beehivvenewsapi/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/mkkia/api/kia-test-object/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/happy2purchase/api/freebooks-api2/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/herosAPI/api/image-search13/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/ealkan2003/api/demographical-data-from-turkey/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/contactnewsyedi/api/super-keyword-magic-tool/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/vikash738/api/codesofcountry1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/illmagination/api/the-ultimate-scraper/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/tagizadeorxan/api/billionaires/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/weya1898/api/todo-lsit/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/bradata/api/consulta-de-cpf-cadastro-de-pessoas-fisicas/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/tomgood17/api/file-scanner1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/Lifecomesfromwithin/api/https-x8ki-letl-twmt-n7-xano-io-api-3juedyut/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/Sakibur-Karim/api/latest-laptop-deals1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/aaslaouireda-bFjiCsSyAti/api/phone-validator1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/miguel.aka.kelter/api/outsystems-community-api/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/datacoints/api/datacoints/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/freegeoipapp/api/freecurrencyapi-free-currency-data/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/hck/api/european-ip-to-household-income/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/fzany/api/random-nigerian-names/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/drango/api/crowdfunding-hot-list/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/nadkabbani/api/hull-id-boat-hin-decoder/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/aml630/api/inflation/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/databox2/api/scraper-stack/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/OkothPius/api/climate-live1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/mo.rodrigo/api/codigospostales-mexico/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/matthewdmarx/api/ultimate-whois-lookup/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/nuancenet-nuancenet/api/language-nuance-detector/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/duongminhlong/api/test1856/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/letsscrape/api/trulia-real-estate-scraper/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/dicolink/api/dicolink/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/cyrano-conseil-cyrano-conseil-default/api/lyngwa/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/letscrape-6bRBa3QguO5/api/real-time-perspectives-search/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/armen-tAzEEKImt/api/geography-game-api/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/strataconsultingllc/api/zumper-api/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/metaapi-metaapi-default/api/metaapi-mindfulness-quotes/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/Yogleads/api/email-to-linkedin1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/javaer/api/sneaker-sku-database1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/usamamern/api/apollo-io1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/mr.point96/api/diagnostics-code-list/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/adityapandey217/api/youtube-video-download-api/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/zackogoma-KfA3BmmOc8M/api/climate-change-data/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/diegomarcello-v3DhCh--prz/api/octadata/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/kunalkp1710/api/mrt/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/badr286.test/api/give_command/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/sohaib.shabbir424/api/livestock/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/drazazora/api/twitter-user-id/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/kecomek553/api/temp-mail33/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/mahamcodes/api/users-list4/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/slangsync-slangsync/api/colloquial-language-assimilator/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/febe3d/api/soap45/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/oceanrock/api/moz-da-pa-private/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/data-immo-data-immo-default/api/seloger-api/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/CMunroe/api/blackbox/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/anvesh9652/api/crypto-ranking1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/builtwith/api/builtwith-domain/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/rahilkasaragod198/api/celebrity-biography/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/lokumpay/api/data-leak-credential-monitor/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/omarmhaimdat/api/tiktok-api6/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/computerportal7/api/sheet4/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/uncertain-identity-uncertain-identity-default/api/safak1/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/relevantal-dot-com-relevantal-dot-com-default/api/quora-data-posts-questions-experts-search-results-data-provider/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']
# https://rapidapi.com/parracj/api/crops/
# ['API-BASKETBALLFREEMIUMVerified✓ByAPI-SPORTS', 'Updated 8 months ago', 'SportsPopularity9.9 / 10Latency314msService Level100%Health CheckN/A']

# %%
import re
import mysql.connector

# Connect to MySQL
cnx = mysql.connector.connect(
    host='xxx',
    user='xxx',
    password='xxx',
    database='xxx'
)
cursor = cnx.cursor()

insert_api_info = "INSERT INTO api_info (base_url, category, last_updated, endpoint_des, popularity, latency, service_level, api_url, hostname) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"

# Iterate over the items in the api_details dictionary
for base_url, info in api_info.items():
    base_url = base_url[:255]
    category = info['category']
    last_updated = info['last_updated']
    endpoint_des = info['endpoint_des']
    popularity = info['popularity']
    latency = info['latency']
    service_level = info['service_level']
    api_url = info['api_url']
    hostname = info['hostname']

    # Check if URL already exists in the database
    select_query = "SELECT base_url FROM api_info WHERE base_url = %s"
    cursor.execute(select_query, (base_url,))
    existing_url = cursor.fetchone()

    if existing_url:
        print(f"URL {base_url} already exists in the database. Skipping insertion.")
    else:
        # Execute the insert operation for each URL and details
        cursor.execute(insert_api_info, (base_url, category, last_updated, endpoint_des, popularity, latency, service_level, api_url, hostname))
        
        # Commit the changes and close the connection
cnx.commit()
cnx.close()
