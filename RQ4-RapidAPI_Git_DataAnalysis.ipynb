# %% [markdown]
# ### RQ4

# %%
import matplotlib.pyplot as plt

# Define the popularity ranges
popularity_ranges = ['1-1.9', '2-2.9', '3-3.9', '4-4.9', '5-5.9', '6-6.9', '7-7.9', '8-8.9', '9-10']

# Function to count occurrences in a list for each range
def count_occurrences(popularity_list):
    counts = [0] * len(popularity_ranges)
    for pop in popularity_list:
        index = int(pop) if pop == 10 else int(pop // 1)
        if 1 <= index <= 9:
            counts[index - 1] += 1
    return counts

# Count occurrences in both lists
skilled_counts = count_occurrences(skilled_popularity)
average_counts = count_occurrences(average_popularity)
novice_counts = count_occurrences(novice_popularity)


# Total count of each list
total_skilled = sum(skilled_counts)
total_average = sum(average_counts)
total_novice = sum(novice_counts)

# Calculate percentages
skilled_percentages = [count / total_skilled * 100 if total_skilled != 0 else 0 for count in skilled_counts]
average_percentages = [count / total_average * 100 if total_average != 0 else 0 for count in average_counts]
novice_percentages = [count / total_novice * 100 if total_novice != 0 else 0 for count in novice_counts]

# Plotting
x = range(len(popularity_ranges))
plt.figure(figsize=(4, 4))
plt.plot(x, skilled_percentages, color='blue', label='Skilled developers')
plt.plot(x, average_percentages, color='darkorange', label='Average developers')
plt.plot(x, novice_percentages, color='green',label='Novice developers')

plt.xlabel('Popularity range')
plt.ylabel('Percentage of services (%)')
plt.title('Services in popularity range')
plt.xticks(x, popularity_ranges, fontsize = 7)
plt.legend()
plt.ylim(0, 100) 
plt.yticks(range(0, 101, 25))
plt.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
plt.tight_layout(pad=1.1)

plt.savefig(r'D:\RapidAPI\RapidAPI\devF_popularity.pdf', format='pdf')

plt.show()

# %%
import matplotlib.pyplot as plt

# Define the latency ranges
latency_ranges = ['1-99', '100-299', '300-599', '600-999', '1000-9999', '10000-99999']

# Function to count occurrences in a list for each range
def count_occurrences(latency_list):
    counts = [0] * len(latency_ranges)
    for latency in latency_list:
        latency = int(latency)
        if latency >= 1 and latency <= 99:
            counts[0] += 1
        elif latency >= 100 and latency <= 299:
            counts[1] += 1
        elif latency >= 300 and latency <= 599:
            counts[2] += 1
        elif latency >= 600 and latency <= 999:
            counts[3] += 1
        elif latency >= 1000 and latency <= 9999:
            counts[4] += 1
        elif latency >= 10000 and latency <= 99999:
            counts[5] += 1
    return counts

# Count occurrences in both lists
skilled_counts = count_occurrences(skilled_latency)
average_counts = count_occurrences(average_latency)
novice_counts = count_occurrences(novice_latency)


# Total count of each list
total_skilled = sum(skilled_counts)
total_average = sum(average_counts)
total_novice = sum(novice_counts)

# Calculate percentages
skilled_percentages = [count / total_skilled * 100 if total_skilled != 0 else 0 for count in skilled_counts]
average_percentages = [count / total_average * 100 if total_average != 0 else 0 for count in average_counts]
novice_percentages = [count / total_novice * 100 if total_novice != 0 else 0 for count in novice_counts]

latency_ranges[-1] = '>10000'
# Plotting
x = range(len(latency_ranges))
plt.figure(figsize=(4, 4))
plt.plot(x, skilled_percentages, color='blue', label='Skilled developers')
plt.plot(x, average_percentages, color='darkorange', label='Average developers')
plt.plot(x, novice_percentages, color='green',label='Novice developers')
plt.xlabel('Latency range (ms)')
plt.ylabel('Percentage of services (%)')
plt.title('Services in latency range')
plt.xticks(x, latency_ranges, fontsize=7)
plt.legend()
plt.ylim(0, 100) 
plt.yticks(range(0, 101, 25))
plt.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
plt.tight_layout()
plt.savefig(r'xx\Desktop\RapidAPI\devF_latency.pdf', format='pdf')

plt.show()

# %%
import matplotlib.pyplot as plt

# Define the service level ranges
service_level_ranges = ['10-90', '91-95', '96', '97', '98', '99', '100']

# Function to count occurrences in a list for each range
def count_occurrences(service_level_list):
    counts = [0] * len(service_level_ranges)
    for service_level in service_level_list:
        service_level = int(service_level)
        if service_level >= 10 and service_level <= 90:
            counts[0] += 1
        elif service_level >= 91 and service_level <= 95:
            counts[1] += 1
        elif service_level == 96:
            counts[2] += 1
        elif service_level == 97:
            counts[3] += 1
        elif service_level == 98:
            counts[4] += 1
        elif service_level == 99:
            counts[5] += 1
        elif service_level == 100:
            counts[6] += 1
    return counts

# Count occurrences in both lists
skilled_counts = count_occurrences(skilled_service_level)
average_counts = count_occurrences(average_service_level)
novice_counts = count_occurrences(novice_service_level)


# Total count of each list
total_skilled = sum(skilled_counts)
total_average = sum(average_counts)
total_novice = sum(novice_counts)

# Calculate percentages
skilled_percentages = [count / total_skilled * 100 if total_skilled != 0 else 0 for count in skilled_counts]
average_percentages = [count / total_average * 100 if total_average != 0 else 0 for count in average_counts]
novice_percentages = [count / total_novice * 100 if total_novice != 0 else 0 for count in novice_counts]

# Plotting
x = range(len(service_level_ranges))
plt.figure(figsize=(4, 4))
plt.plot(x, skilled_percentages, color='blue', label='Skilled developers')
plt.plot(x, average_percentages, color='darkorange', label='Average developers')
plt.plot(x, novice_percentages, color='green',label='Novice developers')
plt.xlabel('Service Level range (%)')
plt.ylabel('Percentage of services (%)')
plt.title('Services in service level range')
plt.xticks(x, service_level_ranges, fontsize=8)
plt.legend()
plt.ylim(0, 100) 
plt.yticks(range(0, 101, 25))
plt.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
plt.tight_layout()
plt.savefig(r'C:xx\Desktop\RapidAPI\devF_serviceLevel.pdf', format='pdf')

plt.show()

# %%
import matplotlib.pyplot as plt

# Define the pricing ranges
pricing_ranges = ['0', '0-0.01', '0.01-0.1', '0.1-1', '1-1000']

# Function to count occurrences in a list for each range
def count_occurrences(pricing_list):
    counts = [0] * len(pricing_ranges)
    for pricing in pricing_list:
        pricing = float(pricing)
        if pricing == 0:
            counts[0] += 1
        elif pricing > 0 and pricing <= 0.01:
            counts[1] += 1
        elif pricing > 0.01 and pricing <= 0.1:
            counts[2] += 1
        elif pricing > 0.1 and pricing <= 1:
            counts[3] += 1
        elif pricing > 1 and pricing <= 1000:
            counts[4] += 1
    return counts

# Count occurrences in both lists
skilled_counts = count_occurrences(skilled_pricing)
average_counts = count_occurrences(average_pricing)
novice_counts = count_occurrences(novice_pricing)


# Total count of each list
total_skilled = sum(skilled_counts)
total_average = sum(average_counts)
total_novice = sum(novice_counts)

# Calculate percentages
skilled_percentages = [count / total_skilled * 100 if total_skilled != 0 else 0 for count in skilled_counts]
average_percentages = [count / total_average * 100 if total_average != 0 else 0 for count in average_counts]
novice_percentages = [count / total_novice * 100 if total_novice != 0 else 0 for count in novice_counts]

# Plotting
x = range(len(pricing_ranges))
plt.figure(figsize=(4, 4))
plt.plot(x, skilled_percentages, color='blue', label='Skilled developers')
plt.plot(x, average_percentages, color='darkorange', label='Average developers')
plt.plot(x, novice_percentages, color='green',label='Novice developers')
plt.xlabel('Pricing range (cost per request($))')
plt.ylabel('Percentage of services (%)')
plt.title('Services in pricing range')
plt.xticks(x, pricing_ranges, fontsize=8)
plt.legend()
plt.ylim(0, 100) 
plt.yticks(range(0, 101, 20))
plt.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
plt.tight_layout()
plt.savefig(r'C:xx\Desktop\RapidAPI\devF_pricing.pdf', format='pdf')

plt.show()

# %%
import matplotlib.pyplot as plt

# Define the document ranges
doc_ranges = ['2', '1', '0']

# Function to count occurrences in a list for each range
def count_occurrences(doc_list):
    counts = [0] * len(doc_ranges)
    for doc in doc_list:
        if doc is not None:  # Skip None values
            doc = int(doc)
            if doc == 2:
                counts[0] += 1
            elif doc == 1:
                counts[1] += 1
            elif doc == 0:
                counts[2] += 1
    return counts

# Count occurrences in both lists
skilled_counts = count_occurrences(skilled_doc)
average_counts = count_occurrences(average_doc)
novice_counts = count_occurrences(novice_doc)


# Total count of each list
total_skilled = sum(skilled_counts)
total_average = sum(average_counts)
total_novice = sum(novice_counts)

# Calculate percentages
skilled_percentages = [count / total_skilled * 100 if total_skilled != 0 else 0 for count in skilled_counts]
average_percentages = [count / total_average * 100 if total_average != 0 else 0 for count in average_counts]
novice_percentages = [count / total_novice * 100 if total_novice != 0 else 0 for count in novice_counts]

# Plotting
x = range(len(doc_ranges))
doc_ranges[-1] = 'Good'
doc_ranges[-2] = 'Average'
doc_ranges[-3] = 'Poor'
plt.figure(figsize=(4, 4))
plt.plot(x, skilled_percentages, color='blue', label='Skilled developers')
plt.plot(x, average_percentages, color='darkorange', label='Average developers')
plt.plot(x, novice_percentages, color='green',label='Novice developers')
plt.xlabel('Support from service provider')
plt.ylabel('Percentage of services (%)')
plt.title('Service provider\'s support')
plt.xticks(x, doc_ranges, fontsize=8)
plt.legend()
plt.ylim(0, 100) 
plt.yticks(range(0, 101, 25))
plt.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
plt.tight_layout()
plt.savefig(r'C:xxDesktop\RapidAPI\devF_devF_ServiceProviderSupp.pdf', format='pdf')

plt.show()

# %%
import matplotlib.pyplot as plt

# Define the communication ranges
com_ranges = ['0', '1-100', '100-1000000']

# Function to count occurrences in a list for each range
def count_occurrences(com_list):
    counts = [0] * len(com_ranges)
    for com in com_list:
        if com is not None:  # Skip None values
            com = float(com)
            if com == 0:
                counts[0] += 1
            elif 1 <= com <= 100:
                counts[1] += 1
            elif com > 100:
                counts[2] += 1
    return counts

# Count occurrences in both lists
skilled_counts = count_occurrences(skilled_doc)
average_counts = count_occurrences(average_doc)
novice_counts = count_occurrences(novice_doc)


# Total count of each list
total_skilled = sum(skilled_counts)
total_average = sum(average_counts)
total_novice = sum(novice_counts)

# Calculate percentages
skilled_percentages = [count / total_skilled * 100 if total_skilled != 0 else 0 for count in skilled_counts]
average_percentages = [count / total_average * 100 if total_average != 0 else 0 for count in average_counts]
novice_percentages = [count / total_novice * 100 if total_novice != 0 else 0 for count in novice_counts]

# Plotting
x = range(len(com_ranges))
com_ranges[-1] = 'Good'
com_ranges[-2] = 'Average'
com_ranges[-3] = 'Poor'
plt.figure(figsize=(4, 4))
plt.plot(x, skilled_percentages, color='blue', label='Skilled developers')
plt.plot(x, average_percentages, color='darkorange', label='Average developers')
plt.plot(x, novice_percentages, color='green',label='Novice developers')
plt.xlabel('Support from Community')
plt.ylabel('Percentage of services (%)')
plt.title('Community support')
plt.xticks(x, com_ranges, fontsize=8)
plt.legend()
plt.ylim(0, 100) 
plt.yticks(range(0, 101, 25))
plt.grid(True, linestyle='--', linewidth=0.5, color='lightgray')
plt.tight_layout()
plt.savefig(r'xx\Desktop\RapidAPI\devF_CommSupp.pdf', format='pdf')

plt.show()
